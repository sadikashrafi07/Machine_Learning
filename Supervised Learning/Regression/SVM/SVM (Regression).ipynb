# %% [markdown]
# # Support Vector Regression

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Real estate.csv")

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
y=df['Y house price of unit area']
x = df.drop(['No','Y house price of unit area'], axis=1)

# %%
import seaborn as sns
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.scatterplot(x='Y house price of unit area',y='X1 transaction date',data=df)
plt.subplot(2,2,2)
sns.scatterplot(x='Y house price of unit area',y='X2 house age',data=df)
plt.subplot(2,2,3)
sns.scatterplot(x='Y house price of unit area',y='X4 number of convenience stores',data=df)
plt.subplot(2,2,4)
sns.scatterplot(x='Y house price of unit area',y='X3 distance to the nearest MRT station',data=df)
# Out:
# <Axes: xlabel='Y house price of unit area', ylabel='X3 distance to the nearest MRT station'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(x,y)
# Out:
# SVR()

# %%
regressor.score(x,y)
# Out:
# 0.6134781298372696

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
result=r2_score(y_test,y_pred)
print(result)
# Out:
# 0.5936283898512629
